# %%
import numpy as np
import pandas as pd

quiz_df= pd.read_csv("C:/Users/Admin/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding= 'latin-1')
print(quiz_df)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
#Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation

quiz_df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
#Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?
quiz_df.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
#What is the total number and percentage of missing data in 2014 to 3 decimal places?
missing_data=quiz_df['Y2014'].isnull().sum()
print(missing_data)
percentage= (missing_data/len(quiz_df['Y2014']))*100
print(percentage)
# Out:
# 1589
# 2.6073544131401474

# %%
#4)What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?
mean=quiz_df['Y2017'].mean()
print(mean)
standard_deviation= quiz_df['Y2017'].std()
print(standard_deviation)
# Out:
# 140.917764860268
# 1671.8623590572788

# %%
#What is the total number of unique countries in the dataset?
quiz_df['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
#What is the total Protein supply quantity in Madagascar in 2015?
q=quiz_df.loc[quiz_df['Area']=='Madagascar']
q.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                    15351     318888        630819
# Export Quantity                             13416     279445        614744
# Fat supply quantity (g/capita/day)          14319     299405         75924
# Feed                                         4515      94030        193235
# Food                                        14190     295817        565620
# Food supply (kcal/capita/day)               14319     299405         73704
# Food supply quantity (kg/capita/yr)         14190     295817         70950
# Import Quantity                             14319     297945        622821
# Losses                                       7095     148102        281765
# Other uses (non-food)                        6579     138246        262854
# Processing                                   9804     201929        389956
# ...

# %%
#Which year had the least correlation with ‘Element Code’?
y1= print(quiz_df['Element Code'].corr(quiz_df['Y2014']))
y2= print(quiz_df['Element Code'].corr(quiz_df['Y2015']))
y3= print(quiz_df['Element Code'].corr(quiz_df['Y2016']))
y4= print(quiz_df['Element Code'].corr(quiz_df['Y2017']))
y5= print(quiz_df['Element Code'].corr(quiz_df['Y2018']))
# Out:
# 0.024456819495222142
# 0.02388919930164082
# 0.023443997584961178
# 0.024254007760045347
# 0.02427857195351955

# %%
#Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?
quiz_df.groupby('Element').count()
quiz_df.loc[quiz_df['Element']== 'Processing'].sum()
# Out:
# Area Code                                                  271940
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 5350416
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                             10313310
# Element         ProcessingProcessingProcessingProcessingProces...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                    282923.0
# Y2015                                                    287929.0
# Y2016                                                    280631.0
# Y2017                                                    292836.0
# Y2018                                                    308429.0
# dtype: object

# %%
#Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in2017?
quiz_df.groupby('Area').count()
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                           1313       1313  1313          1313
# Angola                            1424       1424  1424          1424
# Benin                             1285       1285  1285          1285
# Botswana                          1378       1378  1378          1378
# Burkina Faso                      1409       1409  1409          1409
# Cabo Verde                        1260       1260  1260          1260
# Cameroon                          1460       1460  1460          1460
# Central African Republic          1344       1344  1344          1344
# Chad                              1343       1343  1343          1343
# Comoros                             45         45    45            45
# Congo                             1413       1413  1413          1413
# Côte d'Ivoire                     1467       1467  1467          1467
# ...

# %%
quiz_df.sort_values('Y2017')
# Out:
#        Area Code                         Area  Item Code  \
# 16481         59                        Egypt       2908
# 16512         59                        Egypt       2537
# 39032        144                   Mozambique       2532
# 39016        144                   Mozambique       2907
# 57092        215  United Republic of Tanzania       2913
# ...          ...                          ...        ...
# 60208        181                     Zimbabwe       2582
# 60256        181                     Zimbabwe       2602
# 60355        181                     Zimbabwe       2616
# 60357        181                     Zimbabwe       2616
# 60646        181                     Zimbabwe       2734
#
#                        Item  Element Code          Element         Unit  \
# 16481           Sugar Crops          5072  Stock Variation  1000 tonnes
# 16512            Sugar beet          5072  Stock Variation  1000 tonnes
# ...

# %%
#)Answer the following questions based on the African food production dataset provided by the FAO website already provided What is the total sum of Wine produced in 2015 and 2018 respectively
quiz_df.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...
